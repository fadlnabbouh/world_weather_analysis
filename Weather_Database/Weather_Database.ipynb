# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
from datetime import datetime
from config import weather_api_key
import requests

# %%
# Creating a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # add unique city to list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

# %%
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through all the cities in our list
for i, city in enumerate(cities):
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i>=50):
        set_count += 1
        record_count = 1 
    #create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+") 
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_current_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vanimo
# Processing Record 2 of Set 1 | tuatapere
# Processing Record 3 of Set 1 | olinda
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | nizhniy novgorod
# Processing Record 8 of Set 1 | zumarraga
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | grindavik
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | narsaq
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | longyearbyen
# Processing Record 19 of Set 1 | isangel
# Processing Record 20 of Set 1 | samarai
# Processing Record 21 of Set 1 | flinders
# Processing Record 22 of Set 1 | garden city
# Processing Record 23 of Set 1 | moussoro
# Processing Record 24 of Set 1 | xining
# Processing Record 25 of Set 1 | fairbanks
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | rio gallegos
# Processing Record 28 of Set 1 | kajaani
# Processing Record 29 of Set 1 | novobirilyussy
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | shamkhal
# Processing Record 33 of Set 1 | hasaki
# Processing Record 34 of Set 1 | sitka
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | nara
# Processing Record 40 of Set 1 | deoria
# Processing Record 41 of Set 1 | kavieng
# Processing Record 42 of Set 1 | matagami
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | alekseyevsk
# Processing Record 45 of Set 1 | okha
# Processing Record 46 of Set 1 | haines junction
# Processing Record 47 of Set 1 | carutapera
# Processing Record 48 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | victoria
# Processing Record 1 of Set 2 | solnechnyy
# Processing Record 2 of Set 2 | snyder
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | cockburn town
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | avarua
# Processing Record 7 of Set 2 | hervey bay
# Processing Record 8 of Set 2 | mackay
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | sri aman
# Processing Record 11 of Set 2 | mastic beach
# Processing Record 12 of Set 2 | pisco
# Processing Record 13 of Set 2 | qaqortoq
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | sur
# Processing Record 16 of Set 2 | maloshuyka
# City not found. Skipping...
# Processing Record 17 of Set 2 | chapais
# Processing Record 18 of Set 2 | escondido
# Processing Record 19 of Set 2 | chuy
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | khatanga
# Processing Record 23 of Set 2 | lompoc
# Processing Record 24 of Set 2 | chokurdakh
# Processing Record 25 of Set 2 | abha
# Processing Record 26 of Set 2 | aguimes
# Processing Record 27 of Set 2 | noumea
# Processing Record 28 of Set 2 | bethel
# Processing Record 29 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 2 | salalah
# Processing Record 33 of Set 2 | busselton
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | severobaykalsk
# Processing Record 36 of Set 2 | broken hill
# Processing Record 37 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 2 | jiwani
# Processing Record 39 of Set 2 | cherskiy
# Processing Record 40 of Set 2 | inuvik
# Processing Record 41 of Set 2 | shingu
# Processing Record 42 of Set 2 | mombetsu
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | pasighat
# Processing Record 45 of Set 2 | bluff
# Processing Record 46 of Set 2 | esperance
# Processing Record 47 of Set 2 | waddan
# Processing Record 48 of Set 2 | cayenne
# Processing Record 49 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 2 | namibe
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 3 | kodiak
# Processing Record 4 of Set 3 | leninsk
# Processing Record 5 of Set 3 | grand-santi
# Processing Record 6 of Set 3 | ternate
# Processing Record 7 of Set 3 | mitchell
# Processing Record 8 of Set 3 | malacatepec
# Processing Record 9 of Set 3 | oistins
# Processing Record 10 of Set 3 | tchaourou
# Processing Record 11 of Set 3 | broome
# Processing Record 12 of Set 3 | maltahohe
# Processing Record 13 of Set 3 | gornopravdinsk
# Processing Record 14 of Set 3 | geraldton
# Processing Record 15 of Set 3 | prado
# Processing Record 16 of Set 3 | eskil
# Processing Record 17 of Set 3 | ilulissat
# Processing Record 18 of Set 3 | dingle
# Processing Record 19 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 3 | murmashi
# Processing Record 21 of Set 3 | maldonado
# Processing Record 22 of Set 3 | yarada
# Processing Record 23 of Set 3 | coffs harbour
# Processing Record 24 of Set 3 | teahupoo
# Processing Record 25 of Set 3 | adrar
# Processing Record 26 of Set 3 | poboru
# Processing Record 27 of Set 3 | hithadhoo
# Processing Record 28 of Set 3 | imbituba
# Processing Record 29 of Set 3 | mahebourg
# Processing Record 30 of Set 3 | dejen
# Processing Record 31 of Set 3 | macenta
# Processing Record 32 of Set 3 | quatre cocos
# Processing Record 33 of Set 3 | loandjili
# Processing Record 34 of Set 3 | nanortalik
# Processing Record 35 of Set 3 | tunduma
# Processing Record 36 of Set 3 | upernavik
# Processing Record 37 of Set 3 | port elizabeth
# Processing Record 38 of Set 3 | bredasdorp
# Processing Record 39 of Set 3 | mana
# Processing Record 40 of Set 3 | ulladulla
# Processing Record 41 of Set 3 | luganville
# Processing Record 42 of Set 3 | airai
# Processing Record 43 of Set 3 | komsomolskiy
# Processing Record 44 of Set 3 | uray
# Processing Record 45 of Set 3 | sorland
# Processing Record 46 of Set 3 | kotri
# Processing Record 47 of Set 3 | alofi
# Processing Record 48 of Set 3 | latung
# Processing Record 49 of Set 3 | tokmak
# Processing Record 50 of Set 3 | codrington
# Processing Record 1 of Set 4 | mecca
# Processing Record 2 of Set 4 | goure
# Processing Record 3 of Set 4 | gravdal
# Processing Record 4 of Set 4 | tuktoyaktuk
# Processing Record 5 of Set 4 | khor
# Processing Record 6 of Set 4 | samur
# Processing Record 7 of Set 4 | tiksi
# Processing Record 8 of Set 4 | rock hill
# Processing Record 9 of Set 4 | soyo
# Processing Record 10 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 4 | mount gambier
# Processing Record 12 of Set 4 | bengkulu
# Processing Record 13 of Set 4 | dunedin
# Processing Record 14 of Set 4 | cidreira
# Processing Record 15 of Set 4 | deh rawud
# City not found. Skipping...
# Processing Record 16 of Set 4 | kulhudhuffushi
# Processing Record 17 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 18 of Set 4 | westport
# Processing Record 19 of Set 4 | indramayu
# Processing Record 20 of Set 4 | torbay
# Processing Record 21 of Set 4 | kerman
# Processing Record 22 of Set 4 | woodward
# Processing Record 23 of Set 4 | terme
# Processing Record 24 of Set 4 | smithers
# Processing Record 25 of Set 4 | kaitangata
# Processing Record 26 of Set 4 | jiaozuo
# Processing Record 27 of Set 4 | ancud
# Processing Record 28 of Set 4 | iskateley
# Processing Record 29 of Set 4 | chumikan
# Processing Record 30 of Set 4 | linxia
# Processing Record 31 of Set 4 | grand bend
# Processing Record 32 of Set 4 | bandarbeyla
# Processing Record 33 of Set 4 | iqaluit
# Processing Record 34 of Set 4 | arraial do cabo
# Processing Record 35 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 4 | kabardinka
# Processing Record 37 of Set 4 | vestmannaeyjar
# Processing Record 38 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 4 | luena
# Processing Record 40 of Set 4 | kalmunai
# Processing Record 41 of Set 4 | georgetown
# Processing Record 42 of Set 4 | yumen
# Processing Record 43 of Set 4 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 44 of Set 4 | sobolevo
# Processing Record 45 of Set 4 | sambava
# Processing Record 46 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 4 | forquilhinha
# Processing Record 48 of Set 4 | tiarei
# Processing Record 49 of Set 4 | kruisfontein
# Processing Record 50 of Set 4 | huarmey
# Processing Record 1 of Set 5 | hobyo
# Processing Record 2 of Set 5 | mahanoro
# Processing Record 3 of Set 5 | aklavik
# Processing Record 4 of Set 5 | souillac
# Processing Record 5 of Set 5 | lianran
# Processing Record 6 of Set 5 | muzquiz
# City not found. Skipping...
# Processing Record 7 of Set 5 | shubarkuduk
# Processing Record 8 of Set 5 | lalibela
# Processing Record 9 of Set 5 | progreso
# Processing Record 10 of Set 5 | port lincoln
# Processing Record 11 of Set 5 | severo-kurilsk
# Processing Record 12 of Set 5 | gomel
# Processing Record 13 of Set 5 | ahipara
# Processing Record 14 of Set 5 | blind river
# Processing Record 15 of Set 5 | banepa
# Processing Record 16 of Set 5 | champerico
# Processing Record 17 of Set 5 | karratha
# Processing Record 18 of Set 5 | barcelos
# Processing Record 19 of Set 5 | hamilton
# Processing Record 20 of Set 5 | leningradskiy
# Processing Record 21 of Set 5 | maryville
# Processing Record 22 of Set 5 | ribeira grande
# Processing Record 23 of Set 5 | mandalgovi
# Processing Record 24 of Set 5 | chincholi
# Processing Record 25 of Set 5 | zolotinka
# City not found. Skipping...
# Processing Record 26 of Set 5 | kropotkin
# Processing Record 27 of Set 5 | okhotsk
# Processing Record 28 of Set 5 | chauk
# Processing Record 29 of Set 5 | pevek
# Processing Record 30 of Set 5 | sulurpeta
# City not found. Skipping...
# Processing Record 31 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 5 | panguna
# Processing Record 33 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 5 | tshane
# Processing Record 36 of Set 5 | kassala
# Processing Record 37 of Set 5 | podporozhye
# Processing Record 38 of Set 5 | yulara
# Processing Record 39 of Set 5 | sao joao da barra
# Processing Record 40 of Set 5 | santa vitoria do palmar
# Processing Record 41 of Set 5 | swellendam
# Processing Record 42 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 5 | idah
# Processing Record 44 of Set 5 | kijang
# Processing Record 45 of Set 5 | saint-philippe
# Processing Record 46 of Set 5 | sola
# Processing Record 47 of Set 5 | zheleznodorozhnyy
# Processing Record 48 of Set 5 | cilegon
# Processing Record 49 of Set 5 | ormara
# Processing Record 50 of Set 5 | uige
# Processing Record 1 of Set 6 | vardo
# Processing Record 2 of Set 6 | fortuna
# Processing Record 3 of Set 6 | somovo
# Processing Record 4 of Set 6 | bam
# Processing Record 5 of Set 6 | talnakh
# Processing Record 6 of Set 6 | sao felix do xingu
# Processing Record 7 of Set 6 | aboyne
# Processing Record 8 of Set 6 | mardin
# Processing Record 9 of Set 6 | portland
# Processing Record 10 of Set 6 | klaksvik
# Processing Record 11 of Set 6 | bontang
# Processing Record 12 of Set 6 | wagar
# Processing Record 13 of Set 6 | mitsamiouli
# Processing Record 14 of Set 6 | balkhash
# Processing Record 15 of Set 6 | gat
# Processing Record 16 of Set 6 | pietarsaari
# Processing Record 17 of Set 6 | lavrentiya
# Processing Record 18 of Set 6 | chandigarh
# Processing Record 19 of Set 6 | san andres
# Processing Record 20 of Set 6 | ayr
# Processing Record 21 of Set 6 | niamey
# Processing Record 22 of Set 6 | wad madani
# Processing Record 23 of Set 6 | luanda
# Processing Record 24 of Set 6 | banda aceh
# Processing Record 25 of Set 6 | oeiras
# Processing Record 26 of Set 6 | lorengau
# Processing Record 27 of Set 6 | lagoa
# Processing Record 28 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 6 | muros
# Processing Record 30 of Set 6 | boyolangu
# Processing Record 31 of Set 6 | san policarpo
# Processing Record 32 of Set 6 | husainabad
# Processing Record 33 of Set 6 | aconibe
# Processing Record 34 of Set 6 | baiyin
# Processing Record 35 of Set 6 | mogadishu
# Processing Record 36 of Set 6 | bull savanna
# Processing Record 37 of Set 6 | mayo
# Processing Record 38 of Set 6 | marzuq
# Processing Record 39 of Set 6 | coihaique
# Processing Record 40 of Set 6 | butembo
# Processing Record 41 of Set 6 | the valley
# Processing Record 42 of Set 6 | chimbote
# Processing Record 43 of Set 6 | arman
# Processing Record 44 of Set 6 | olafsvik
# Processing Record 45 of Set 6 | mamallapuram
# Processing Record 46 of Set 6 | meulaboh
# Processing Record 47 of Set 6 | raudeberg
# Processing Record 48 of Set 6 | emerald
# Processing Record 49 of Set 6 | sibolga
# Processing Record 50 of Set 6 | santa maria
# Processing Record 1 of Set 7 | mayumba
# Processing Record 2 of Set 7 | palmer
# Processing Record 3 of Set 7 | zenzeli
# Processing Record 4 of Set 7 | tasiilaq
# Processing Record 5 of Set 7 | morondava
# Processing Record 6 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 7 of Set 7 | saint-pierre
# Processing Record 8 of Set 7 | verkhnyaya inta
# Processing Record 9 of Set 7 | rutul
# Processing Record 10 of Set 7 | kahului
# Processing Record 11 of Set 7 | san patricio
# Processing Record 12 of Set 7 | provideniya
# Processing Record 13 of Set 7 | pundaguitan
# Processing Record 14 of Set 7 | cabo san lucas
# Processing Record 15 of Set 7 | neryungri
# Processing Record 16 of Set 7 | grand forks
# Processing Record 17 of Set 7 | hambantota
# Processing Record 18 of Set 7 | odweyne
# Processing Record 19 of Set 7 | nikolskoye
# Processing Record 20 of Set 7 | mujiayingzi
# Processing Record 21 of Set 7 | sidney
# Processing Record 22 of Set 7 | vera cruz
# Processing Record 23 of Set 7 | skibbereen
# Processing Record 24 of Set 7 | ayan
# Processing Record 25 of Set 7 | kedrovyy
# Processing Record 26 of Set 7 | kununurra
# Processing Record 27 of Set 7 | northview
# Processing Record 28 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 29 of Set 7 | ossora
# Processing Record 30 of Set 7 | gelemso
# Processing Record 31 of Set 7 | jambi
# Processing Record 32 of Set 7 | leh
# Processing Record 33 of Set 7 | faanui
# Processing Record 34 of Set 7 | gushikawa
# Processing Record 35 of Set 7 | saldanha
# Processing Record 36 of Set 7 | ampanihy
# Processing Record 37 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 38 of Set 7 | tezu
# Processing Record 39 of Set 7 | fare
# Processing Record 40 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 7 | luzhou
# Processing Record 42 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 7 | seoul
# Processing Record 44 of Set 7 | haapiti
# Processing Record 45 of Set 7 | san cristobal
# Processing Record 46 of Set 7 | ha giang
# Processing Record 47 of Set 7 | bambous virieux
# Processing Record 48 of Set 7 | moron
# Processing Record 49 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 7 | najran
# Processing Record 1 of Set 8 | machali
# Processing Record 2 of Set 8 | road town
# Processing Record 3 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 4 of Set 8 | tarko-sale
# Processing Record 5 of Set 8 | camalu
# Processing Record 6 of Set 8 | port-gentil
# Processing Record 7 of Set 8 | raisen
# Processing Record 8 of Set 8 | sao filipe
# Processing Record 9 of Set 8 | videira
# Processing Record 10 of Set 8 | nioro
# Processing Record 11 of Set 8 | ponta do sol
# Processing Record 12 of Set 8 | sao jose da coroa grande
# Processing Record 13 of Set 8 | douglas
# Processing Record 14 of Set 8 | acapulco
# Processing Record 15 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 16 of Set 8 | dondo
# Processing Record 17 of Set 8 | veraval
# Processing Record 18 of Set 8 | vanavara
# Processing Record 19 of Set 8 | shimoda
# Processing Record 20 of Set 8 | humaita
# Processing Record 21 of Set 8 | zavetnoye
# Processing Record 22 of Set 8 | newport
# Processing Record 23 of Set 8 | ugoofaaru
# Processing Record 24 of Set 8 | praia da vitoria
# Processing Record 25 of Set 8 | oskaloosa
# Processing Record 26 of Set 8 | marsh harbour
# Processing Record 27 of Set 8 | yaan
# Processing Record 28 of Set 8 | maroua
# Processing Record 29 of Set 8 | gaoual
# Processing Record 30 of Set 8 | turinsk
# Processing Record 31 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 32 of Set 8 | southbridge
# Processing Record 33 of Set 8 | lazaro cardenas
# Processing Record 34 of Set 8 | maceio
# Processing Record 35 of Set 8 | waingapu
# Processing Record 36 of Set 8 | nouadhibou
# Processing Record 37 of Set 8 | kalga
# Processing Record 38 of Set 8 | san carlos de bariloche
# Processing Record 39 of Set 8 | kavaratti
# Processing Record 40 of Set 8 | bria
# Processing Record 41 of Set 8 | hami
# Processing Record 42 of Set 8 | batetskiy
# Processing Record 43 of Set 8 | makinsk
# Processing Record 44 of Set 8 | lagunas
# Processing Record 45 of Set 8 | morlaix
# Processing Record 46 of Set 8 | ostersund
# Processing Record 47 of Set 8 | rock springs
# Processing Record 48 of Set 8 | leshukonskoye
# Processing Record 49 of Set 8 | koumac
# Processing Record 50 of Set 8 | saskylakh
# Processing Record 1 of Set 9 | cefalu
# Processing Record 2 of Set 9 | riberalta
# Processing Record 3 of Set 9 | thohoyandou
# Processing Record 4 of Set 9 | pimentel
# Processing Record 5 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 7 of Set 9 | alice springs
# Processing Record 8 of Set 9 | necochea
# Processing Record 9 of Set 9 | poum
# Processing Record 10 of Set 9 | lynn haven
# Processing Record 11 of Set 9 | vao
# Processing Record 12 of Set 9 | sinnamary
# Processing Record 13 of Set 9 | lusambo
# Processing Record 14 of Set 9 | shu
# Processing Record 15 of Set 9 | luderitz
# Processing Record 16 of Set 9 | awbari
# Processing Record 17 of Set 9 | bonthe
# Processing Record 18 of Set 9 | norman wells
# Processing Record 19 of Set 9 | northam
# Processing Record 20 of Set 9 | laguna
# Processing Record 21 of Set 9 | hofn
# Processing Record 22 of Set 9 | inhambane
# Processing Record 23 of Set 9 | saint-louis
# Processing Record 24 of Set 9 | vyksa
# Processing Record 25 of Set 9 | gao
# Processing Record 26 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 27 of Set 9 | ust-omchug
# Processing Record 28 of Set 9 | pattaya
# Processing Record 29 of Set 9 | port hedland
# Processing Record 30 of Set 9 | poronaysk
# Processing Record 31 of Set 9 | clyde river
# Processing Record 32 of Set 9 | zhezkazgan
# Processing Record 33 of Set 9 | berlevag
# Processing Record 34 of Set 9 | mahanje
# Processing Record 35 of Set 9 | shizunai
# Processing Record 36 of Set 9 | deputatskiy
# Processing Record 37 of Set 9 | umuahia
# Processing Record 38 of Set 9 | sjoholt
# Processing Record 39 of Set 9 | port blair
# Processing Record 40 of Set 9 | alenquer
# Processing Record 41 of Set 9 | iaciara
# Processing Record 42 of Set 9 | bara
# Processing Record 43 of Set 9 | pampa
# Processing Record 44 of Set 9 | fara in sabina
# Processing Record 45 of Set 9 | batemans bay
# Processing Record 46 of Set 9 | ambilobe
# Processing Record 47 of Set 9 | horta
# Processing Record 48 of Set 9 | harper
# Processing Record 49 of Set 9 | taltal
# Processing Record 50 of Set 9 | boa vista
# Processing Record 1 of Set 10 | gisors
# Processing Record 2 of Set 10 | aksarka
# Processing Record 3 of Set 10 | pizarro
# Processing Record 4 of Set 10 | rio grande
# Processing Record 5 of Set 10 | viadana
# Processing Record 6 of Set 10 | erzin
# Processing Record 7 of Set 10 | pala
# Processing Record 8 of Set 10 | kamaishi
# Processing Record 9 of Set 10 | thinadhoo
# Processing Record 10 of Set 10 | antsohihy
# Processing Record 11 of Set 10 | gorodishche
# Processing Record 12 of Set 10 | targusor
# Processing Record 13 of Set 10 | belmonte
# Processing Record 14 of Set 10 | wroclaw
# Processing Record 15 of Set 10 | ucluelet
# Processing Record 16 of Set 10 | itupiranga
# Processing Record 17 of Set 10 | ponta delgada
# Processing Record 18 of Set 10 | maniitsoq
# Processing Record 19 of Set 10 | tonj
# Processing Record 20 of Set 10 | nizhniy odes
# Processing Record 21 of Set 10 | porto novo
# Processing Record 22 of Set 10 | taoudenni
# Processing Record 23 of Set 10 | las cruces
# Processing Record 24 of Set 10 | chazuta
# Processing Record 25 of Set 10 | pokrovsk
# Processing Record 26 of Set 10 | gasa
# Processing Record 27 of Set 10 | socorro
# Processing Record 28 of Set 10 | teguldet
# Processing Record 29 of Set 10 | beringovskiy
# Processing Record 30 of Set 10 | at-bashi
# Processing Record 31 of Set 10 | katsuura
# Processing Record 32 of Set 10 | traverse city
# Processing Record 33 of Set 10 | kwinana
# Processing Record 34 of Set 10 | guerrero negro
# Processing Record 35 of Set 10 | bobo dioulasso
# Processing Record 36 of Set 10 | wattegama
# Processing Record 37 of Set 10 | williams lake
# Processing Record 38 of Set 10 | bayan
# Processing Record 39 of Set 10 | talara
# Processing Record 40 of Set 10 | merauke
# Processing Record 41 of Set 10 | scituate
# Processing Record 42 of Set 10 | saint george
# Processing Record 43 of Set 10 | medea
# Processing Record 44 of Set 10 | kargat
# Processing Record 45 of Set 10 | ixtapa
# Processing Record 46 of Set 10 | grand gaube
# Processing Record 47 of Set 10 | jiuquan
# Processing Record 48 of Set 10 | scottsburgh
# City not found. Skipping...
# Processing Record 49 of Set 10 | petropavlovskoye
# Processing Record 50 of Set 10 | cabedelo
# Processing Record 1 of Set 11 | maragogi
# Processing Record 2 of Set 11 | hodal
# Processing Record 3 of Set 11 | martapura
# Processing Record 4 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 5 of Set 11 | beira
# Processing Record 6 of Set 11 | pangody
# Processing Record 7 of Set 11 | wajima
# Processing Record 8 of Set 11 | erenhot
# Processing Record 9 of Set 11 | palmas de monte alto
# Processing Record 10 of Set 11 | dayong
# Processing Record 11 of Set 11 | yar-sale
# Processing Record 12 of Set 11 | khorixas
# Processing Record 13 of Set 11 | tura
# Processing Record 14 of Set 11 | canavieiras
# Processing Record 15 of Set 11 | bafq
# Processing Record 16 of Set 11 | viedma
# Processing Record 17 of Set 11 | griffith
# Processing Record 18 of Set 11 | paamiut
# Processing Record 19 of Set 11 | henties bay
# Processing Record 20 of Set 11 | lukovetskiy
# Processing Record 21 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 22 of Set 11 | naze
# Processing Record 23 of Set 11 | venice
# Processing Record 24 of Set 11 | bealanana
# Processing Record 25 of Set 11 | mayskiy
# Processing Record 26 of Set 11 | yenagoa
# Processing Record 27 of Set 11 | dongsheng
# Processing Record 28 of Set 11 | besikduzu
# Processing Record 29 of Set 11 | dromolaxia
# Processing Record 30 of Set 11 | seymchan
# Processing Record 31 of Set 11 | pavlovsk
# Processing Record 32 of Set 11 | igarka
# Processing Record 33 of Set 11 | tres arroyos
# Processing Record 34 of Set 11 | faridan
# City not found. Skipping...
# Processing Record 35 of Set 11 | saint anthony
# Processing Record 36 of Set 11 | limbang
# Processing Record 37 of Set 11 | kirakira
# Processing Record 38 of Set 11 | ketchikan
# Processing Record 39 of Set 11 | tongliao
# Processing Record 40 of Set 11 | mazatlan
# Processing Record 41 of Set 11 | ginda
# Processing Record 42 of Set 11 | valley city
# Processing Record 43 of Set 11 | nuqui
# Processing Record 44 of Set 11 | shangzhi
# Processing Record 45 of Set 11 | bac lieu
# Processing Record 46 of Set 11 | roebourne
# Processing Record 47 of Set 11 | eltham
# Processing Record 48 of Set 11 | turka
# Processing Record 49 of Set 11 | north platte
# Processing Record 50 of Set 11 | half moon bay
# Processing Record 1 of Set 12 | coquimbo
# Processing Record 2 of Set 12 | touros
# Processing Record 3 of Set 12 | neuquen
# Processing Record 4 of Set 12 | tula
# Processing Record 5 of Set 12 | soe
# Processing Record 6 of Set 12 | kiunga
# Processing Record 7 of Set 12 | rawson
# Processing Record 8 of Set 12 | north myrtle beach
# Processing Record 9 of Set 12 | belle fourche
# Processing Record 10 of Set 12 | sioux lookout
# Processing Record 11 of Set 12 | antalaha
# Processing Record 12 of Set 12 | pathalgaon
# Processing Record 13 of Set 12 | am timan
# Processing Record 14 of Set 12 | dolores
# Processing Record 15 of Set 12 | araouane
# Processing Record 16 of Set 12 | ouro preto do oeste
# Processing Record 17 of Set 12 | kargil
# Processing Record 18 of Set 12 | kismayo
# Processing Record 19 of Set 12 | ninotsminda
# Processing Record 20 of Set 12 | helmsdale
# Processing Record 21 of Set 12 | thul
# Processing Record 22 of Set 12 | belmopan
# Processing Record 23 of Set 12 | katherine
# Processing Record 24 of Set 12 | filadelfia
# Processing Record 25 of Set 12 | metro
# Processing Record 26 of Set 12 | springbok
# Processing Record 27 of Set 12 | tecoanapa
# Processing Record 28 of Set 12 | concepcion del uruguay
# Processing Record 29 of Set 12 | puerto baquerizo moreno
# Processing Record 30 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 12 | torit
# Processing Record 32 of Set 12 | cornwall
# Processing Record 33 of Set 12 | hovd
# Processing Record 34 of Set 12 | rocha
# Processing Record 35 of Set 12 | goldsboro
# Processing Record 36 of Set 12 | honningsvag
# Processing Record 37 of Set 12 | byron bay
# Processing Record 38 of Set 12 | sakakah
# Processing Record 39 of Set 12 | vestmanna
# Processing Record 40 of Set 12 | khandyga
# Processing Record 41 of Set 12 | kutum
# Processing Record 42 of Set 12 | bilma
# Processing Record 43 of Set 12 | pueblo
# Processing Record 44 of Set 12 | cvikov
# Processing Record 45 of Set 12 | karatuzskoye
# Processing Record 46 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 47 of Set 12 | la cruz
# Processing Record 48 of Set 12 | batticaloa
# Processing Record 49 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 50 of Set 12 | teknaf
# Processing Record 1 of Set 13 | pleasanton
# Processing Record 2 of Set 13 | harindanga
# Processing Record 3 of Set 13 | bowen
# Processing Record 4 of Set 13 | camana
# Processing Record 5 of Set 13 | evensk
# Processing Record 6 of Set 13 | impfondo
# Processing Record 7 of Set 13 | xai-xai
# Processing Record 8 of Set 13 | cururupu
# Processing Record 9 of Set 13 | ringebu
# Processing Record 10 of Set 13 | krasnogorsk
# Processing Record 11 of Set 13 | bathsheba
# Processing Record 12 of Set 13 | namatanai
# Processing Record 13 of Set 13 | toora-khem
# Processing Record 14 of Set 13 | altamira
# Processing Record 15 of Set 13 | waverly
# Processing Record 16 of Set 13 | kawalu
# Processing Record 17 of Set 13 | lamu
# Processing Record 18 of Set 13 | havre-saint-pierre
# Processing Record 19 of Set 13 | saurimo
# Processing Record 20 of Set 13 | aquiraz
# Processing Record 21 of Set 13 | bundaberg
# Processing Record 22 of Set 13 | nangwa
# Processing Record 23 of Set 13 | angoche
# Processing Record 24 of Set 13 | namtsy
# Processing Record 25 of Set 13 | kitimat
# Processing Record 26 of Set 13 | marsa matruh
# Processing Record 27 of Set 13 | sangar
# Processing Record 28 of Set 13 | natal
# Processing Record 29 of Set 13 | sigli
# Processing Record 30 of Set 13 | sabang
# Processing Record 31 of Set 13 | langsa
# Processing Record 32 of Set 13 | bubaque
# Processing Record 33 of Set 13 | omboue
# Processing Record 34 of Set 13 | poya
# Processing Record 35 of Set 13 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 36 of Set 13 | caravelas
# Processing Record 37 of Set 13 | loiza
# Processing Record 38 of Set 13 | flin flon
# Processing Record 39 of Set 13 | debrecen
# Processing Record 40 of Set 13 | sakaiminato
# Processing Record 41 of Set 13 | troitsko-pechorsk
# Processing Record 42 of Set 13 | andenes
# Processing Record 43 of Set 13 | albanel
# Processing Record 44 of Set 13 | luchegorsk
# Processing Record 45 of Set 13 | lobito
# Processing Record 46 of Set 13 | aberdeen
# Processing Record 47 of Set 13 | kargasok
# Processing Record 48 of Set 13 | carauari
# Processing Record 49 of Set 13 | riedlingen
# Processing Record 50 of Set 13 | benghazi
# Processing Record 1 of Set 14 | camacha
# Processing Record 2 of Set 14 | coari
# Processing Record 3 of Set 14 | warri
# Processing Record 4 of Set 14 | antofagasta
# Processing Record 5 of Set 14 | rae bareli
# Processing Record 6 of Set 14 | lasa
# Processing Record 7 of Set 14 | marathopolis
# City not found. Skipping...
# Processing Record 8 of Set 14 | ocampo
# Processing Record 9 of Set 14 | tiznit
# Processing Record 10 of Set 14 | hinton
# Processing Record 11 of Set 14 | sligo
# Processing Record 12 of Set 14 | sahuaripa
# Processing Record 13 of Set 14 | miraflores
# Processing Record 14 of Set 14 | sterling
# Processing Record 15 of Set 14 | marica
# Processing Record 16 of Set 14 | nizwa
# Processing Record 17 of Set 14 | dharchula
# Processing Record 18 of Set 14 | khani
# Processing Record 19 of Set 14 | heyang
# Processing Record 20 of Set 14 | nishihara
# Processing Record 21 of Set 14 | rio muerto
# Processing Record 22 of Set 14 | svetlyy
# Processing Record 23 of Set 14 | songea
# Processing Record 24 of Set 14 | denpasar
# Processing Record 25 of Set 14 | zonguldak
# Processing Record 26 of Set 14 | weyburn
# Processing Record 27 of Set 14 | cam ranh
# Processing Record 28 of Set 14 | polunochnoye
# Processing Record 29 of Set 14 | maarianhamina
# Processing Record 30 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 14 | sieut
# Processing Record 32 of Set 14 | zhigansk
# Processing Record 33 of Set 14 | havoysund
# Processing Record 34 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 14 | santa isabel do rio negro
# Processing Record 36 of Set 14 | belogorsk
# Processing Record 37 of Set 14 | jinchang
# Processing Record 38 of Set 14 | kushmurun
# Processing Record 39 of Set 14 | avera
# Processing Record 40 of Set 14 | belyy yar
# Processing Record 41 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 42 of Set 14 | guerrero
# Processing Record 43 of Set 14 | lodeynoye pole
# Processing Record 44 of Set 14 | north bend
# Processing Record 45 of Set 14 | clovis
# Processing Record 46 of Set 14 | toronto
# Processing Record 47 of Set 14 | athabasca
# Processing Record 48 of Set 14 | zaysan
# Processing Record 49 of Set 14 | opuwo
# Processing Record 50 of Set 14 | lensk
# Processing Record 1 of Set 15 | les cayes
# Processing Record 2 of Set 15 | canaries
# Processing Record 3 of Set 15 | baracoa
# Processing Record 4 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 5 of Set 15 | korla
# Processing Record 6 of Set 15 | russell
# Processing Record 7 of Set 15 | yeniseysk
# Processing Record 8 of Set 15 | almaty
# Processing Record 9 of Set 15 | waitati
# Processing Record 10 of Set 15 | yerbogachen
# Processing Record 11 of Set 15 | thenzawl
# Processing Record 12 of Set 15 | bukachacha
# Processing Record 13 of Set 15 | baglung
# Processing Record 14 of Set 15 | aykhal
# Processing Record 15 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 16 of Set 15 | port moresby
# Processing Record 17 of Set 15 | shasta lake
# Processing Record 18 of Set 15 | tanout
# Processing Record 19 of Set 15 | zemetchino
# Processing Record 20 of Set 15 | nuuk
# Processing Record 21 of Set 15 | sorong
# Processing Record 22 of Set 15 | sault sainte marie
# Processing Record 23 of Set 15 | digby
# Processing Record 24 of Set 15 | secusigiu
# Processing Record 25 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 26 of Set 15 | turukhansk
# Processing Record 27 of Set 15 | eidfjord
# Processing Record 28 of Set 15 | rezzato
# Processing Record 29 of Set 15 | college
# Processing Record 30 of Set 15 | milingimbi
# City not found. Skipping...
# Processing Record 31 of Set 15 | umm jarr
# City not found. Skipping...
# Processing Record 32 of Set 15 | aksu
# Processing Record 33 of Set 15 | sarangani
# Processing Record 34 of Set 15 | chlorakas
# Processing Record 35 of Set 15 | xinmin
# Processing Record 36 of Set 15 | simoes
# Processing Record 37 of Set 15 | zaozerne
# Processing Record 38 of Set 15 | itoman
# Processing Record 39 of Set 15 | tual
# Processing Record 40 of Set 15 | asfi
# Processing Record 41 of Set 15 | rabo de peixe
# Processing Record 42 of Set 15 | den helder
# Processing Record 43 of Set 15 | honiara
# Processing Record 44 of Set 15 | pekan
# Processing Record 45 of Set 15 | hailar
# Processing Record 46 of Set 15 | gazli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Vanimo      PG  -2.6741  141.3028     83.82        72
# 1         Tuatapere      NZ -46.1333  167.6833     49.82        77
# 2            Olinda      BR  -8.0089  -34.8553     74.93        83
# 3              Hilo      US  19.7297 -155.0900     82.80        69
# 4           Rikitea      PF -23.1203 -134.9692     72.63        66
# 5  Nizhniy Novgorod      RU  56.3287   44.0020     53.11        62
# 6         Zumarraga      PH  11.6388  124.8417     81.30        81
# 7          Hermanus      ZA -34.4187   19.2345     54.90        74
# 8         Grindavik      IS  63.8424  -22.4338     50.56        81
# 9         Cape Town      ZA -33.9258   18.4232     55.11        94
#
#    Cloudiness  Wind Speed Current Description
# 0          83        2.86       broken clouds
# 1          91        8.34     overcast clouds
# 2          75        8.81       broken clouds
# 3           1       12.66           clear sky
# 4          83       13.87       broken clouds
# 5           0       11.27           clear sky
# 6         100        3.20     overcast clouds
# 7         100        6.96     overcast clouds
# 8          90       29.01     overcast clouds
# 9          97        2.89                 fog

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
